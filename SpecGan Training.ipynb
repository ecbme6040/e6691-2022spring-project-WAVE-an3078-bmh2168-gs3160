# %%
from utils.utils import *
from utils.specgan import *
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader,Dataset
from tqdm import tqdm
import pickle

device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
GPU=True
if not GPU:
    device= 'cpu'
# Data Params
DATA_PATH='./data/drums'
AUDIO_LENGTH = 16384 #[16384, 32768, 65536] 
SAMPLING_RATE = 16000
NORMALIZE_AUDIO = False 
CHANNELS = 1

#Model params
LATENT_NOISE_DIM = 100
MODEL_CAPACITY=64
LAMBDA_GP = 10

#Training params
TRAIN_DISCRIM = 5 # how many times to train the discriminator for one generator step
EPOCHS = 500
BATCH_SIZE=25
LR_GEN = 1e-4
LR_DISC = 1e-4 # alternative is bigger lr instead of high TRAIN_DISCRIM
BETA1 = 0.5
BETA2 = 0.9


# Dataset and Dataloader

#load into vram
#train_set = AudioDataset_ram(DATA_PATH,sample_rate=SAMPLING_RATE,number_samples=AUDIO_LENGTH,extension='wav',std=NORMALIZE_AUDIO,device=device,spectrogram=True)

#load into cpu ram
train_set = AudioDataset_ram(DATA_PATH,sample_rate=SAMPLING_RATE,number_samples=AUDIO_LENGTH,extension='wav',std=NORMALIZE_AUDIO,device='cpu',spectrogram=True)

#load at training from disk
#train_set = AudioDataset(DATA_PATH,sample_rate=SAMPLING_RATE,number_samples=AUDIO_LENGTH,extension='wav',std=NORMALIZE_AUDIO,spectrogram=True)

print(train_set.__len__())
# Out:
# loading sample 3000: 100%|█████████████████████████████████████████████████████| 3002/3002 [00:53<00:00, 56.52sample/s]
# 3002

# %%
import os
if not os.path.exists('./save/specgen'):
    os.makedirs('./save/specgen')
    
if not os.path.exists('./save/specdisc'):
    os.makedirs('./save/specdisc')
    
if not os.path.exists('./save/specfake'):
    os.makedirs('./save/specfake')
    
if not os.path.exists('./save/spechist'):
    os.makedirs('./save/spechist')

# %%
train_loader = DataLoader(dataset=train_set,
                          batch_size=BATCH_SIZE,
                          shuffle=True,
                          num_workers=4)
#generator and discriminator
spec_gen = SpecGenerator(d=MODEL_CAPACITY, c=CHANNELS ,inplace=True).to(device)
spec_disc = SpecDiscriminator(d=MODEL_CAPACITY, c=CHANNELS ,inplace=True).to(device)

#random weights init
initialize_weights(spec_gen)
initialize_weights(spec_disc)

spec_gen.train()
spec_disc.train()

#Adam optim for both generator iand discriminator
optimizer_gen = optim.Adam(spec_gen.parameters(), lr=LR_GEN, betas=(BETA1, BETA2))
optimizer_disc = optim.Adam(spec_disc.parameters(), lr=LR_DISC, betas=(BETA1, BETA2))

start=-1
if start>0:
    spec_disc.load_state_dict(torch.load('./save/specdisc/disc_'+str(start)+'_93.pt'))
    spec_gen.load_state_dict(torch.load('./save/specgen/gen_'+str(start)+'_93.pt'))

# %%
#training
import pickle
step = start+1 # for restart from saved weights
hist=[]
for epoch in range(EPOCHS):
    with tqdm(train_loader, unit="batch") as tepoch: 
        for batch_id, real_audio in enumerate(tepoch):  
            tepoch.set_description(f"Epoch {epoch}")
            real_audio = real_audio.to(device)
            
            #Train Discriminator 
            for train_step in range(TRAIN_DISCRIM):
                noise = torch.randn(real_audio.shape[0], LATENT_NOISE_DIM).to(device)
                #print(noise.shape)
                fake_audio = spec_gen(noise)
                disc_real = spec_disc(real_audio).reshape(-1)
                disc_fake = spec_disc(fake_audio).reshape(-1)
                loss_disc = wasserstein_loss(spec_disc, real_audio, fake_audio,device,LAMBDA = LAMBDA_GP,spec_gan=True)
                spec_disc.zero_grad()
                loss_disc.backward(retain_graph=True)
                optimizer_disc.step()

            # Train the generator!
            all_wasserstein = spec_disc(fake_audio).reshape(-1)
            loss = -torch.mean(all_wasserstein)
            spec_gen.zero_grad()
            loss.backward()
            optimizer_gen.step()
            step += 1
            # Print progress, save stats, and save model
            hist.append([loss.item(),loss_disc.item()])
            if batch_id % 5 == 0 and batch_id > 0:
                tepoch.set_postfix(gen_loss=loss.item(), disc_loss=loss_disc.item())

    #if batch_id % 100 == 0 and batch_id > 0:
    with open('./save/spechist/hist_'+str(step)+'_'+str(epoch)+'_'+str(batch_id)+'.pkl', 'wb') as f:
        pickle.dump(hist, f)
    torch.save(spec_gen.state_dict(), './save/specgen/gen_'+str(epoch)+'_'+str(step)+'.pt')
    torch.save(spec_disc.state_dict(), './save/specdisc/spec_'+str(epoch)+'_'+str(step)+'.pt')
    with torch.no_grad():
        fake = spec_gen(noise)
        torch.save(fake, './save/specfake/fake_'+str(epoch)+'_'+str(step)+'.pt')
# Out:
# Epoch 0: 100%|██████████████████████████████████| 121/121 [02:26<00:00,  1.21s/batch, disc_loss=7.19e+4, gen_loss=-195]
# Epoch 1: 100%|█████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-3.07e+5, gen_loss=-295]
# Epoch 2: 100%|███████████████████████████████████| 121/121 [02:28<00:00,  1.23s/batch, disc_loss=5.4e+4, gen_loss=-215]
# Epoch 3: 100%|██████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=3.14e+4, gen_loss=-248]
# Epoch 4: 100%|█████████████████████████████████| 121/121 [02:28<00:00,  1.22s/batch, disc_loss=-5.16e+5, gen_loss=-927]
# Epoch 5: 100%|██████████████████████████████████| 121/121 [02:28<00:00,  1.23s/batch, disc_loss=5.91e+3, gen_loss=-546]
# Epoch 6: 100%|█████████████████████████████| 121/121 [02:28<00:00,  1.23s/batch, disc_loss=-2.21e+6, gen_loss=-2.83e+3]
# Epoch 7: 100%|█████████████████████████████| 121/121 [02:28<00:00,  1.23s/batch, disc_loss=-1.52e+6, gen_loss=-2.25e+3]
# Epoch 8: 100%|█████████████████████████████| 121/121 [02:28<00:00,  1.23s/batch, disc_loss=-2.16e+6, gen_loss=-2.53e+3]
# Epoch 9: 100%|█████████████████████████████████| 121/121 [02:28<00:00,  1.23s/batch, disc_loss=-1.33e+5, gen_loss=-364]
# Epoch 10: 100%|████████████████████████████████| 121/121 [02:28<00:00,  1.23s/batch, disc_loss=-1.04e+5, gen_loss=-239]
# Epoch 11: 100%|████████████████████████████████| 121/121 [02:29<00:00,  1.23s/batch, disc_loss=-4.56e+5, gen_loss=-137]
# Epoch 12: 100%|█████████████████████████████████| 121/121 [02:28<00:00,  1.23s/batch, disc_loss=-9.8e+4, gen_loss=-301]
# Epoch 13: 100%|████████████████████████████████| 121/121 [02:28<00:00,  1.23s/batch, disc_loss=-1.04e+3, gen_loss=-486]
# Epoch 14: 100%|████████████████████████████████| 121/121 [02:28<00:00,  1.23s/batch, disc_loss=-4.63e+5, gen_loss=-490]
# Epoch 15: 100%|████████████████████████████████| 121/121 [02:28<00:00,  1.23s/batch, disc_loss=-4.73e+5, gen_loss=-485]
# Epoch 16: 100%|█████████████████████████████████| 121/121 [02:28<00:00,  1.23s/batch, disc_loss=1.46e+4, gen_loss=-281]
# Epoch 17: 100%|████████████████████████████████| 121/121 [02:31<00:00,  1.25s/batch, disc_loss=-3.77e+4, gen_loss=-425]
# Epoch 18: 100%|████████████████████████████████| 121/121 [02:32<00:00,  1.26s/batch, disc_loss=-1.69e+5, gen_loss=-683]
# Epoch 19: 100%|████████████████████████████████| 121/121 [02:31<00:00,  1.25s/batch, disc_loss=-1.49e+5, gen_loss=-366]
# Epoch 20: 100%|███████████████████████████████████| 121/121 [02:32<00:00,  1.26s/batch, disc_loss=-2e+5, gen_loss=-500]
# Epoch 21: 100%|████████████████████████████████| 121/121 [02:28<00:00,  1.23s/batch, disc_loss=-1.31e+4, gen_loss=-632]
# Epoch 22: 100%|████████████████████████████████| 121/121 [02:31<00:00,  1.25s/batch, disc_loss=-1.97e+5, gen_loss=-761]
# Epoch 23: 100%|███████████████████████████████| 121/121 [02:29<00:00,  1.24s/batch, disc_loss=-1.18e+6, gen_loss=-1e+3]
# Epoch 24: 100%|████████████████████████████████| 121/121 [02:29<00:00,  1.24s/batch, disc_loss=-3.44e+5, gen_loss=-628]
# Epoch 25: 100%|████████████████████████████████| 121/121 [02:29<00:00,  1.23s/batch, disc_loss=-2.71e+5, gen_loss=-715]
# Epoch 26: 100%|████████████████████████████| 121/121 [02:29<00:00,  1.23s/batch, disc_loss=-1.89e+6, gen_loss=-1.72e+3]
# Epoch 27: 100%|████████████████████████████████| 121/121 [02:29<00:00,  1.23s/batch, disc_loss=-4.63e+5, gen_loss=-754]
# Epoch 28: 100%|████████████████████████████████| 121/121 [02:32<00:00,  1.26s/batch, disc_loss=-5.89e+5, gen_loss=-599]
# Epoch 29: 100%|████████████████████████████| 121/121 [02:30<00:00,  1.24s/batch, disc_loss=-1.21e+6, gen_loss=-1.86e+3]
# Epoch 30: 100%|████████████████████████████| 121/121 [02:30<00:00,  1.25s/batch, disc_loss=-4.54e+5, gen_loss=-1.11e+3]
# Epoch 31: 100%|█████████████████████████████████| 121/121 [02:39<00:00,  1.31s/batch, disc_loss=1.15e+5, gen_loss=-792]
# Epoch 32: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-4.08e+5, gen_loss=-620]
# Epoch 33: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-8.68e+4, gen_loss=-523]
# Epoch 34: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-8.27e+4, gen_loss=-499]
# Epoch 35: 100%|█████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.3e+6, gen_loss=-1.16e+3]
# Epoch 36: 100%|██████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=2.9e+4, gen_loss=-681]
# Epoch 37: 100%|██████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=5.3e+4, gen_loss=-410]
# Epoch 38: 100%|████████████████████████████| 121/121 [02:28<00:00,  1.22s/batch, disc_loss=-1.88e+6, gen_loss=-2.62e+3]
# Epoch 39: 100%|████████████████████████████| 121/121 [02:28<00:00,  1.23s/batch, disc_loss=-8.05e+5, gen_loss=-1.44e+3]
# Epoch 40: 100%|████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-3.34e+4, gen_loss=-1.65e+3]
# Epoch 41: 100%|████████████████████████████████| 121/121 [02:28<00:00,  1.22s/batch, disc_loss=-2.34e+5, gen_loss=-899]
# Epoch 42: 100%|████████████████████████████████| 121/121 [02:32<00:00,  1.26s/batch, disc_loss=-1.34e+4, gen_loss=-538]
# Epoch 43: 100%|█████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=1.61e+3, gen_loss=-220]
# Epoch 44: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-6.72e+5, gen_loss=-701]
# Epoch 45: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.13e+5, gen_loss=-768]
# Epoch 46: 100%|███████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-48.5, gen_loss=-316]
# Epoch 47: 100%|████████████████████████████████| 121/121 [02:29<00:00,  1.24s/batch, disc_loss=-9.53e+5, gen_loss=-855]
# Epoch 48: 100%|█████████████████████████████████| 121/121 [02:41<00:00,  1.33s/batch, disc_loss=6.32e+3, gen_loss=-156]
# Epoch 49: 100%|█████████████████████████████████| 121/121 [02:53<00:00,  1.43s/batch, disc_loss=2.41e+3, gen_loss=-573]
# Epoch 50: 100%|████████████████████████████████| 121/121 [02:54<00:00,  1.44s/batch, disc_loss=-8.32e+4, gen_loss=-996]
# Epoch 51: 100%|████████████████████████████████| 121/121 [02:53<00:00,  1.43s/batch, disc_loss=-1.94e+5, gen_loss=-738]
# Epoch 52: 100%|████████████████████████████| 121/121 [02:29<00:00,  1.24s/batch, disc_loss=-4.62e+5, gen_loss=-1.03e+3]
# Epoch 53: 100%|█████████████████████████████| 121/121 [02:30<00:00,  1.25s/batch, disc_loss=-2.3e+6, gen_loss=-3.22e+3]
# Epoch 54: 100%|████████████████████████████████| 121/121 [02:30<00:00,  1.24s/batch, disc_loss=-1.05e+5, gen_loss=-406]
# Epoch 55: 100%|████████████████████████████████| 121/121 [02:29<00:00,  1.23s/batch, disc_loss=-3.85e+5, gen_loss=-485]
# Epoch 56: 100%|████████████████████████████| 121/121 [02:29<00:00,  1.24s/batch, disc_loss=-1.41e+6, gen_loss=-3.29e+3]
# Epoch 57: 100%|█████████████████████████████████| 121/121 [02:30<00:00,  1.24s/batch, disc_loss=-7387.0, gen_loss=-439]
# Epoch 58: 100%|████████████████████████████████| 121/121 [02:41<00:00,  1.34s/batch, disc_loss=-1.66e+5, gen_loss=-504]
# Epoch 59: 100%|█████████████████████████████| 121/121 [03:03<00:00,  1.52s/batch, disc_loss=-7.68e+5, gen_loss=-1.3e+3]
# Epoch 60: 100%|████████████████████████████████| 121/121 [02:39<00:00,  1.32s/batch, disc_loss=-1.69e+5, gen_loss=-737]
# Epoch 61: 100%|█████████████████████████████████| 121/121 [02:30<00:00,  1.24s/batch, disc_loss=2.34e+4, gen_loss=-521]
# Epoch 62: 100%|████████████████████████████████| 121/121 [02:39<00:00,  1.32s/batch, disc_loss=-1.24e+5, gen_loss=-566]
# Epoch 63: 100%|████████████████████████████████| 121/121 [02:29<00:00,  1.23s/batch, disc_loss=-2.32e+3, gen_loss=-319]
# Epoch 64: 100%|█████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=2.61e+4, gen_loss=-831]
# Epoch 65: 100%|████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-5.99e+5, gen_loss=-1.19e+3]
# Epoch 66: 100%|████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.79e+6, gen_loss=-2.03e+3]
# Epoch 67: 100%|████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-4.69e+5, gen_loss=-1.16e+3]
# Epoch 68: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-3.11e+4, gen_loss=-289]
# Epoch 69: 100%|█████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=5.18e+4, gen_loss=-448]
# Epoch 70: 100%|██████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=3.3e+3, gen_loss=-226]
# Epoch 71: 100%|██████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=3.4e+4, gen_loss=-376]
# Epoch 72: 100%|█████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=2.46e+4, gen_loss=-275]
# Epoch 73: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-9.56e+4, gen_loss=-162]
# Epoch 74: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-63173.0, gen_loss=-289]
# Epoch 75: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-4.43e+5, gen_loss=-683]
# Epoch 76: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-2.64e+5, gen_loss=-720]
# Epoch 77: 100%|█████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-2.3e+3, gen_loss=-385]
# Epoch 78: 100%|█████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-5.3e+4, gen_loss=-812]
# Epoch 79: 100%|█████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-2.3e+5, gen_loss=-1.01e+3]
# Epoch 80: 100%|████████████████████████████████| 121/121 [02:29<00:00,  1.24s/batch, disc_loss=-2.35e+5, gen_loss=-768]
# Epoch 81: 100%|████████████████████████████████| 121/121 [02:28<00:00,  1.22s/batch, disc_loss=-5.22e+4, gen_loss=-372]
# Epoch 82: 100%|████████████████████████████████| 121/121 [02:28<00:00,  1.23s/batch, disc_loss=-8.41e+4, gen_loss=-468]
# Epoch 83: 100%|████████████████████████████| 121/121 [02:29<00:00,  1.24s/batch, disc_loss=-1.44e+6, gen_loss=-1.08e+3]
# Epoch 84: 100%|████████████████████████████| 121/121 [02:30<00:00,  1.24s/batch, disc_loss=-2.09e+6, gen_loss=-2.01e+3]
# Epoch 85: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-9.64e+3, gen_loss=-377]
# Epoch 86: 100%|████████████████████████████████| 121/121 [02:28<00:00,  1.22s/batch, disc_loss=-2.34e+5, gen_loss=-196]
# Epoch 87: 100%|████████████████████████████████| 121/121 [02:28<00:00,  1.23s/batch, disc_loss=-1.13e+5, gen_loss=-441]
# Epoch 88: 100%|████████████████████████████| 121/121 [02:29<00:00,  1.23s/batch, disc_loss=-9.53e+5, gen_loss=-3.34e+3]
# Epoch 89: 100%|████████████████████████████████| 121/121 [02:29<00:00,  1.24s/batch, disc_loss=-1.92e+5, gen_loss=-422]
# Epoch 90: 100%|█████████████████████████████████| 121/121 [02:29<00:00,  1.24s/batch, disc_loss=-2.1e+4, gen_loss=-502]
# Epoch 91: 100%|████████████████████████████████| 121/121 [02:28<00:00,  1.23s/batch, disc_loss=-9.78e+4, gen_loss=-562]
# Epoch 92: 100%|████████████████████████████████| 121/121 [02:29<00:00,  1.23s/batch, disc_loss=-5.76e+5, gen_loss=-314]
# Epoch 93: 100%|█████████████████████████████████| 121/121 [02:29<00:00,  1.23s/batch, disc_loss=2.54e+4, gen_loss=-227]
# Epoch 94: 100%|████████████████████████████████| 121/121 [02:28<00:00,  1.22s/batch, disc_loss=-7.13e+3, gen_loss=-165]
# Epoch 95: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-9.77e+3, gen_loss=-586]
# Epoch 96: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-2.54e+5, gen_loss=-660]
# Epoch 97: 100%|████████████████████████████████| 121/121 [02:28<00:00,  1.22s/batch, disc_loss=-1.12e+5, gen_loss=-502]
# Epoch 98: 100%|█████████████████████████████████| 121/121 [02:28<00:00,  1.22s/batch, disc_loss=2.48e+4, gen_loss=-261]
# Epoch 99: 100%|█████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=3.61e+4, gen_loss=-381]
# Epoch 100: 100%|███████████████████████████████| 121/121 [02:28<00:00,  1.22s/batch, disc_loss=-7.77e+5, gen_loss=-571]
# Epoch 101: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=2.71e+4, gen_loss=-678]
# Epoch 102: 100%|███████████████████████████| 121/121 [02:28<00:00,  1.22s/batch, disc_loss=-2.33e+6, gen_loss=-2.06e+3]
# Epoch 103: 100%|████████████████████████████████| 121/121 [02:28<00:00,  1.22s/batch, disc_loss=4.65e+4, gen_loss=-483]
# Epoch 104: 100%|███████████████████████████████| 121/121 [02:28<00:00,  1.23s/batch, disc_loss=-6.88e+5, gen_loss=-833]
# Epoch 105: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=2.53e+4, gen_loss=-340]
# Epoch 106: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-8.54e+5, gen_loss=-1.14e+3]
# Epoch 107: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-9.87e+4, gen_loss=-1.11e+3]
# Epoch 108: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.96e+5, gen_loss=-509]
# Epoch 109: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-7.78e+5, gen_loss=-329]
# Epoch 110: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-4.75e+5, gen_loss=-1.34e+3]
# Epoch 111: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-3.54e+5, gen_loss=-687]
# Epoch 112: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-2.95e+4, gen_loss=-456]
# Epoch 113: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=5.25e+4, gen_loss=-787]
# Epoch 114: 100%|███████████████████████████████| 121/121 [02:28<00:00,  1.22s/batch, disc_loss=-4.16e+5, gen_loss=-877]
# Epoch 115: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-7.23e+5, gen_loss=-896]
# Epoch 116: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.37e+6, gen_loss=-1.66e+3]
# Epoch 117: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-5.47e+4, gen_loss=-395]
# Epoch 118: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-4.63e+5, gen_loss=-1.13e+3]
# Epoch 119: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-7.69e+3, gen_loss=-489]
# Epoch 120: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-5.04e+4, gen_loss=-903]
# Epoch 121: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-2.76e+5, gen_loss=-422]
# Epoch 122: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.67e+5, gen_loss=-758]
# Epoch 123: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-3.12e+4, gen_loss=-196]
# Epoch 124: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-6.63e+5, gen_loss=-635]
# Epoch 125: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=7.26e+3, gen_loss=-528]
# Epoch 126: 100%|███████████████████████████████| 121/121 [02:28<00:00,  1.22s/batch, disc_loss=-3.67e+3, gen_loss=-705]
# Epoch 127: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-5.93e+5, gen_loss=-1.02e+3]
# Epoch 128: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-4.14e+5, gen_loss=-906]
# Epoch 129: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-2.97e+5, gen_loss=-571]
# Epoch 130: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.21e+5, gen_loss=-766]
# Epoch 131: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-9.41e+5, gen_loss=-562]
# Epoch 132: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-3.9e+4, gen_loss=-555]
# Epoch 133: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.88e+5, gen_loss=-918]
# Epoch 134: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-7.36e+4, gen_loss=-402]
# Epoch 135: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-7.48e+4, gen_loss=-469]
# Epoch 136: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.43e+5, gen_loss=-666]
# Epoch 137: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-3.94e+5, gen_loss=-1.12e+3]
# Epoch 138: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-3.47e+5, gen_loss=-781]
# Epoch 139: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=1.15e+4, gen_loss=-245]
# Epoch 140: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.38e+5, gen_loss=-604]
# Epoch 141: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-2.21e+5, gen_loss=-614]
# Epoch 142: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=1.44e+4, gen_loss=-718]
# Epoch 143: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.48e+4, gen_loss=-567]
# Epoch 144: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.14e+6, gen_loss=-2.75e+3]
# Epoch 145: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.01e+6, gen_loss=-1.85e+3]
# Epoch 146: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-2.95e+4, gen_loss=-605]
# Epoch 147: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=1.51e+3, gen_loss=-909]
# Epoch 148: 100%|██████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-8e+4, gen_loss=-567]
# Epoch 149: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-2.41e+6, gen_loss=-1.26e+3]
# Epoch 150: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.55e+5, gen_loss=-418]
# Epoch 151: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=1.02e+4, gen_loss=-485]
# Epoch 152: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=2.45e+3, gen_loss=-415]
# Epoch 153: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-4.12e+5, gen_loss=-908]
# Epoch 154: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=4.85e+4, gen_loss=-323]
# Epoch 155: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-6.3e+3, gen_loss=-895]
# Epoch 156: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-6.73e+5, gen_loss=-1.23e+3]
# Epoch 157: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-2.82e+5, gen_loss=-508]
# Epoch 158: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.16e+6, gen_loss=-1.63e+3]
# Epoch 159: 100%|████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-7.34e+4, gen_loss=-1.1e+3]
# Epoch 160: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-3.14e+5, gen_loss=-998]
# Epoch 161: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-2.7e+5, gen_loss=-931]
# Epoch 162: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.78e+4, gen_loss=-556]
# Epoch 163: 100%|████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.6e+6, gen_loss=-1.89e+3]
# Epoch 164: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.05e+5, gen_loss=-517]
# Epoch 165: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-4.12e+5, gen_loss=-738]
# Epoch 166: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-3.52e+4, gen_loss=-898]
# Epoch 167: 100%|████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-9.7e+5, gen_loss=-1.34e+3]
# Epoch 168: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.81e+4, gen_loss=-210]
# Epoch 169: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.59e+6, gen_loss=-2.83e+3]
# Epoch 170: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-4.05e+5, gen_loss=-729]
# Epoch 171: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-3.03e+4, gen_loss=-665]
# Epoch 172: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.69e+5, gen_loss=-947]
# Epoch 173: 100%|███████████████████████████████| 121/121 [02:29<00:00,  1.24s/batch, disc_loss=-1.87e+5, gen_loss=-980]
# Epoch 174: 100%|███████████████████████████| 121/121 [02:30<00:00,  1.25s/batch, disc_loss=-7.45e+5, gen_loss=-1.01e+3]
# Epoch 175: 100%|████████████████████████████████████| 121/121 [02:29<00:00,  1.24s/batch, disc_loss=619, gen_loss=-746]
# Epoch 176: 100%|████████████████████████████████| 121/121 [02:29<00:00,  1.24s/batch, disc_loss=2.06e+4, gen_loss=-341]
# Epoch 177: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=1.68e+4, gen_loss=-697]
# Epoch 178: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.45e+6, gen_loss=-1.31e+3]
# Epoch 179: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.45e+6, gen_loss=-2.92e+3]
# Epoch 180: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=1.57e+3, gen_loss=-137]
# Epoch 181: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-3.94e+6, gen_loss=-3.53e+3]
# Epoch 182: 100%|███████████████████████████████| 121/121 [02:28<00:00,  1.23s/batch, disc_loss=-2.29e+4, gen_loss=-254]
# Epoch 183: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-8.46e+4, gen_loss=-809]
# Epoch 184: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-4.11e+5, gen_loss=-999]
# Epoch 185: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.98e+5, gen_loss=-381]
# Epoch 186: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-3.14e+4, gen_loss=-625]
# Epoch 187: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-5.56e+4, gen_loss=-381]
# Epoch 188: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.84e+5, gen_loss=-626]
# Epoch 189: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-4.68e+3, gen_loss=-538]
# Epoch 190: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=1.49e+4, gen_loss=-227]
# Epoch 191: 100%|████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-2.1e+6, gen_loss=-2.61e+3]
# Epoch 192: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-4.66e+4, gen_loss=-618]
# Epoch 193: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-2.95e+5, gen_loss=-885]
# Epoch 194: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=1.43e+4, gen_loss=-382]
# Epoch 195: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-8.38e+4, gen_loss=-1.14e+3]
# Epoch 196: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=1.17e+4, gen_loss=-55.7]
# Epoch 197: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.28e+4, gen_loss=-388]
# Epoch 198: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.25e+5, gen_loss=-308]
# Epoch 199: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-8.68e+5, gen_loss=-831]
# Epoch 200: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-6.66e+5, gen_loss=-1.39e+3]
# Epoch 201: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-2.96e+5, gen_loss=-498]
# Epoch 202: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-9.66e+5, gen_loss=-883]
# Epoch 203: 100%|█████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=3.9e+4, gen_loss=-615]
# Epoch 204: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-4.47e+5, gen_loss=-484]
# Epoch 205: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.99e+6, gen_loss=-2.22e+3]
# Epoch 206: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-8.24e+4, gen_loss=-463]
# Epoch 207: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-2.19e+6, gen_loss=-3.42e+3]
# Epoch 208: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.5e+4, gen_loss=-835]
# Epoch 209: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.95e+5, gen_loss=-703]
# Epoch 210: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=1.02e+5, gen_loss=-612]
# Epoch 211: 100%|█████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=2.79e+4, gen_loss=-1.1e+3]
# Epoch 212: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.59e+4, gen_loss=-230]
# Epoch 213: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-7.74e+4, gen_loss=-464]
# Epoch 214: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=1.35e+4, gen_loss=-689]
# Epoch 215: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=5.43e+4, gen_loss=-370]
# Epoch 216: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-4.25e+5, gen_loss=-1.09e+3]
# Epoch 217: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.22e+6, gen_loss=-1.65e+3]
# Epoch 218: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-5.73e+5, gen_loss=-1.23e+3]
# Epoch 219: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-5.67e+5, gen_loss=-352]
# Epoch 220: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-5.12e+4, gen_loss=-343]
# Epoch 221: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-2.44e+6, gen_loss=-4.17e+3]
# Epoch 222: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-9.32e+4, gen_loss=-775]
# Epoch 223: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-8.98e+3, gen_loss=-537]
# Epoch 224: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-4.43e+4, gen_loss=-575]
# Epoch 225: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-7.63e+5, gen_loss=-989]
# Epoch 226: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=1.23e+4, gen_loss=-635]
# Epoch 227: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-1.13e+6, gen_loss=-2.25e+3]
# Epoch 228: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-8.89e+5, gen_loss=-908]
# Epoch 229: 100%|████████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=6.18e+4, gen_loss=-522]
# Epoch 230: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-2.15e+4, gen_loss=-458]
# Epoch 231: 100%|███████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-7.35e+5, gen_loss=-1.32e+3]
# Epoch 232: 100%|███████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-3.23e+5, gen_loss=-932]
# Epoch 233: 100%|████████████████████████████| 121/121 [02:27<00:00,  1.22s/batch, disc_loss=-6.5e+5, gen_loss=-1.13e+3]
# Epoch 234: 100%|███████████████████████████████| 121/121 [02:28<00:00,  1.23s/batch, disc_loss=-3.76e+5, gen_loss=-746]
# Epoch 235: 100%|███████████████████████████████| 121/121 [02:30<00:00,  1.24s/batch, disc_loss=-2.26e+4, gen_loss=-255]
# Epoch 236: 100%|███████████████████████████████| 121/121 [02:30<00:00,  1.24s/batch, disc_loss=-1.85e+5, gen_loss=-544]
# Epoch 237: 100%|███████████████████████████████| 121/121 [02:30<00:00,  1.24s/batch, disc_loss=-7.11e+5, gen_loss=-838]
# Epoch 238: 100%|████████████████████████████████| 121/121 [02:29<00:00,  1.24s/batch, disc_loss=-2.4e+4, gen_loss=-231]
# Epoch 239: 100%|███████████████████████████| 121/121 [02:30<00:00,  1.24s/batch, disc_loss=-4.84e+5, gen_loss=-1.23e+3]
# Epoch 240: 100%|███████████████████████████████| 121/121 [02:29<00:00,  1.23s/batch, disc_loss=-6.52e+5, gen_loss=-950]
# Epoch 241: 100%|███████████████████████████████| 121/121 [02:31<00:00,  1.25s/batch, disc_loss=-6.28e+5, gen_loss=-656]
# Epoch 242: 100%|███████████████████████████| 121/121 [02:29<00:00,  1.23s/batch, disc_loss=-1.18e+6, gen_loss=-1.85e+3]
# Epoch 243: 100%|██████████████████████████████████| 121/121 [02:30<00:00,  1.25s/batch, disc_loss=-55.4, gen_loss=-421]
# Epoch 244: 100%|███████████████████████████| 121/121 [02:30<00:00,  1.24s/batch, disc_loss=-7.57e+5, gen_loss=-1.03e+3]
# Epoch 245: 100%|████████████████████████████████| 121/121 [02:31<00:00,  1.25s/batch, disc_loss=1.87e+4, gen_loss=-444]
# Epoch 246: 100%|██████████████████████████████████| 121/121 [02:30<00:00,  1.24s/batch, disc_loss=-499, gen_loss=-88.9]
# Epoch 247: 100%|███████████████████████████| 121/121 [02:30<00:00,  1.25s/batch, disc_loss=-1.69e+6, gen_loss=-1.29e+3]
# Epoch 248:  12%|███▉                            | 15/121 [00:28<02:04,  1.18s/batch, disc_loss=-1.71e+5, gen_loss=-541]
