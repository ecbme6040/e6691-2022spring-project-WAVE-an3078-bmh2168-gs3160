# %%
#C:\Users\nguye\Downloads\timit\data\lisa\data\timit\raw\TIMIT\TRAIN

# %reload_ext autoreload
# %autoreload 2

from utils.utils import *
from utils.wavegan import *
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader,Dataset
from tqdm import tqdm
import pickle

device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
GPU=True
if not GPU:
    device= 'cpu'
# Data Params
DATA_PATH='./data/piano'
AUDIO_LENGTH = 16384 #[16384, 32768, 65536] 
SAMPLING_RATE = 16000
NORMALIZE_AUDIO = False 
CHANNELS = 1

#Model params
LATENT_NOISE_DIM = 100
MODEL_CAPACITY=64
LAMBDA_GP = 10

#Training params
TRAIN_DISCRIM = 5 # how many times to train the discriminator for one generator step
EPOCHS = 500
BATCH_SIZE=32
LR_GEN = 1e-4
LR_DISC = 1e-4 # alternative is bigger lr instead of high TRAIN_DISCRIM
BETA1 = 0.5
BETA2 = 0.9


# Dataset and Dataloader

#load into vram
train_set = AudioDataset_ram(DATA_PATH,sample_rate=SAMPLING_RATE,number_samples=AUDIO_LENGTH,extension='wav',std=NORMALIZE_AUDIO,device=device)

#load into cpu ram
#train_set = AudioDataset_ram(DATA_PATH,sample_rate=SAMPLING_RATE,number_samples=AUDIO_LENGTH,extension='wav',std=NORMALIZE_AUDIO,device='cpu')

#load at training from disk
#train_set = AudioDataset(DATA_PATH,sample_rate=SAMPLING_RATE,number_samples=AUDIO_LENGTH,extension='wav',std=NORMALIZE_AUDIO,start_only=False)

print(train_set.__len__())
# Out:
# loading sample 1420: 100%|█████████████████████████████████████████████████████| 1426/1426 [00:48<00:00, 29.19sample/s]
# 1426

# %%
from IPython.display import Audio 
from IPython.core.display import display
import torchaudio
import torch
import numpy as np
SAMPLING_RATE=16000


audio_batch=train_set[0].cpu()

def audio_player(audio_batch,autoplay=False):
    
    for i in range(audio_batch.shape[0]):
        display(Audio(audio_batch[i].numpy(), rate=SAMPLING_RATE, autoplay=autoplay))



audio_player(audio_batch)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
train_loader = DataLoader(dataset=train_set,
                          batch_size=BATCH_SIZE,
                          shuffle=True,
                          num_workers=0) #if loading into vram set num_workers to 0
#generator and discriminator
wave_gen = WaveGenerator(d=MODEL_CAPACITY, c=CHANNELS ,inplace=True).to(device)
wave_disc = WaveDiscriminator(d=MODEL_CAPACITY, c=CHANNELS ,inplace=True).to(device)

#random weights init
initialize_weights(wave_gen)
initialize_weights(wave_disc)
wave_gen
wave_disc
wave_gen.train()
wave_disc.train()

#Adam optim for both generator iand discriminator
optimizer_gen = optim.Adam(wave_gen.parameters(), lr=LR_GEN, betas=(BETA1, BETA2))
optimizer_disc = optim.Adam(wave_disc.parameters(), lr=LR_DISC, betas=(BETA1, BETA2))

start=-1
if start>0:
    wave_disc.load_state_dict(torch.load('./save/wavedisc/wave_'+str(start)+'_93.pt'))
    wave_gen.load_state_dict(torch.load('./save/wavegen/gen_'+str(start)+'_93.pt'))

# %%
#training
import pickle
step = start+1 # for restart from saved weights
hist=[]
for epoch in range(EPOCHS):
    with tqdm(train_loader, unit="batch") as tepoch: 
        for batch_id, real_audio in enumerate(tepoch):  
            tepoch.set_description(f"Epoch {epoch}")
            real_audio = real_audio.to(device)
            
            #Train Discriminator 
            for train_step in range(TRAIN_DISCRIM):
                noise = torch.randn(real_audio.shape[0], LATENT_NOISE_DIM).to(device)
                #print(noise.shape)
                fake_audio = wave_gen(noise)
                disc_real = wave_disc(real_audio).reshape(-1)
                disc_fake = wave_disc(fake_audio).reshape(-1)
                loss_disc = wasserstein_loss(wave_disc, real_audio, fake_audio,device,LAMBDA = LAMBDA_GP)
                wave_disc.zero_grad()
                loss_disc.backward(retain_graph=True)
                optimizer_disc.step()

            # Train the generator!
            all_wasserstein = wave_disc(fake_audio).reshape(-1)
            loss = -torch.mean(all_wasserstein)
            wave_gen.zero_grad()
            loss.backward()
            optimizer_gen.step()
            step += 1
            # Print progress, save stats, and save model
            hist.append([loss.item(),loss_disc.item()])
            if batch_id % 5 == 0 and batch_id > 0:
                tepoch.set_postfix(gen_loss=loss.item(), disc_loss=loss_disc.item())

    #if batch_id % 100 == 0 and batch_id > 0:
    with open('./save/wavehist/hist_'+str(step)+'_'+str(epoch)+'_'+str(batch_id)+'.pkl', 'wb') as f:
        pickle.dump(hist, f)
    torch.save(wave_gen.state_dict(), './save/wavegen/gen_'+str(epoch)+'_'+str(step)+'.pt')
    torch.save(wave_disc.state_dict(), './save/wavedisc/wave_'+str(epoch)+'_'+str(step)+'.pt')
    with torch.no_grad():
        fake = wave_gen(noise)
        torch.save(fake, './save/wavefake/fake_'+str(epoch)+'_'+str(step)+'.pt')
# Out:
# Epoch 0: 100%|███████████████████████████████████████| 45/45 [01:18<00:00,  1.74s/batch, disc_loss=4.6, gen_loss=-8.08]
# Epoch 1: 100%|█████████████████████████████████████| 45/45 [01:10<00:00,  1.57s/batch, disc_loss=0.877, gen_loss=-12.5]
# Epoch 2: 100%|██████████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.98, gen_loss=4.39]
# Epoch 3: 100%|██████████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-1.45, gen_loss=16.6]
# Epoch 4: 100%|█████████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-16.8, gen_loss=-43.9]
# Epoch 5: 100%|█████████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=0.465, gen_loss=-48.3]
# Epoch 6: 100%|█████████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.92, gen_loss=-7.86]
# Epoch 7: 100%|██████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=0.339, gen_loss=2.18]
# Epoch 8: 100%|█████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-1.64, gen_loss=-1.47]
# Epoch 9: 100%|█████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.18, gen_loss=-.238]
# Epoch 10: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=0.499, gen_loss=-1.19]
# Epoch 11: 100%|█████████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-1.64, gen_loss=-.26]
# Epoch 12: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.53s/batch, disc_loss=-1.62, gen_loss=-2.11]
# Epoch 13: 100%|██████████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-1.12, gen_loss=1.3]
# Epoch 14: 100%|██████████████████████████████████████| 45/45 [01:08<00:00,  1.53s/batch, disc_loss=-1.3, gen_loss=2.89]
# Epoch 15: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.53s/batch, disc_loss=-1.46, gen_loss=0.175]
# Epoch 16: 100%|█████████████████████████████████████| 45/45 [01:08<00:00,  1.53s/batch, disc_loss=-1.9, gen_loss=-1.31]
# Epoch 17: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-.969, gen_loss=-.762]
# Epoch 18: 100%|█████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-1.47, gen_loss=0.23]
# Epoch 19: 100%|██████████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.23, gen_loss=1.2]
# Epoch 20: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-1.79, gen_loss=-.428]
# Epoch 21: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-3.34, gen_loss=-.563]
# Epoch 22: 100%|█████████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.4, gen_loss=0.234]
# Epoch 23: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.63, gen_loss=-.638]
# Epoch 24: 100%|█████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.66, gen_loss=-.48]
# Epoch 25: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-3.26, gen_loss=-1.11]
# Epoch 26: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.69, gen_loss=-1.75]
# Epoch 27: 100%|█████████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.28, gen_loss=1.33]
# Epoch 28: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.81, gen_loss=0.068]
# Epoch 29: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-3.34, gen_loss=-.251]
# Epoch 30: 100%|█████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-3.36, gen_loss=-.63]
# Epoch 31: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.86, gen_loss=-.0255]
# Epoch 32: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.95, gen_loss=0.275]
# Epoch 33: 100%|█████████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-3.3, gen_loss=-.191]
# Epoch 34: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.75, gen_loss=0.697]
# Epoch 35: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-3.36, gen_loss=-1.01]
# Epoch 36: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-3.04, gen_loss=-.314]
# Epoch 37: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.64, gen_loss=-.724]
# Epoch 38: 100%|█████████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-3.01, gen_loss=1.27]
# Epoch 39: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-3.29, gen_loss=-1.38]
# Epoch 40: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-3.08, gen_loss=0.123]
# Epoch 41: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.42, gen_loss=-.222]
# Epoch 42: 100%|█████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.46, gen_loss=0.29]
# Epoch 43: 100%|█████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.89, gen_loss=1.32]
# Epoch 44: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.95, gen_loss=-.316]
# Epoch 45: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-1.89, gen_loss=0.711]
# Epoch 46: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.95, gen_loss=-.336]
# Epoch 47: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.49, gen_loss=0.138]
# Epoch 48: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.86, gen_loss=-.897]
# Epoch 49: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-3.25, gen_loss=0.215]
# Epoch 50: 100%|███████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2, gen_loss=-.573]
# Epoch 51: 100%|█████████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-1.94, gen_loss=1.35]
# Epoch 52: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.11, gen_loss=-.231]
# Epoch 53: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.35, gen_loss=-.509]
# Epoch 54: 100%|█████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.75, gen_loss=-.45]
# Epoch 55: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.45, gen_loss=-.0516]
# Epoch 56: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.77, gen_loss=0.133]
# Epoch 57: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.78, gen_loss=-.0966]
# Epoch 58: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.85, gen_loss=-.689]
# Epoch 59: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.81, gen_loss=-.148]
# Epoch 60: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.77, gen_loss=-1.04]
# Epoch 61: 100%|█████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.98, gen_loss=1.54]
# Epoch 62: 100%|█████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-1.91, gen_loss=1.01]
# Epoch 63: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.19, gen_loss=0.145]
# Epoch 64: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.43, gen_loss=0.169]
# Epoch 65: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.23, gen_loss=0.258]
# Epoch 66: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.84, gen_loss=-.135]
# Epoch 67: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-1.94, gen_loss=-.305]
# Epoch 68: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.85, gen_loss=0.667]
# Epoch 69: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.75, gen_loss=0.417]
# Epoch 70: 100%|█████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.69, gen_loss=1.01]
# Epoch 71: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.72, gen_loss=-1.16]
# Epoch 72: 100%|█████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.4, gen_loss=0.901]
# Epoch 73: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.66, gen_loss=-.694]
# Epoch 74: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.88, gen_loss=0.473]
# Epoch 75: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.74, gen_loss=-.375]
# Epoch 76: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.71, gen_loss=0.472]
# Epoch 77: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.71, gen_loss=-.0707]
# Epoch 78: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.55, gen_loss=0.473]
# Epoch 79: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.73, gen_loss=-.197]
# Epoch 80: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.49, gen_loss=-.134]
# Epoch 81: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.25, gen_loss=0.653]
# Epoch 82: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.62, gen_loss=-.449]
# Epoch 83: 100%|█████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.56, gen_loss=-.91]
# Epoch 84: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.37, gen_loss=-.468]
# Epoch 85: 100%|██████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.39, gen_loss=-.3]
# Epoch 86: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.98, gen_loss=0.416]
# Epoch 87: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.51, gen_loss=-.238]
# Epoch 88: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.47, gen_loss=-.529]
# Epoch 89: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.44, gen_loss=0.772]
# Epoch 90: 100%|█████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.54, gen_loss=-.74]
# Epoch 91: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.7, gen_loss=0.0582]
# Epoch 92: 100%|█████████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.5, gen_loss=0.233]
# Epoch 93: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.42, gen_loss=0.339]
# Epoch 94: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.48, gen_loss=-.335]
# Epoch 95: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.92, gen_loss=0.897]
# Epoch 96: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.68, gen_loss=0.0695]
# Epoch 97: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.47, gen_loss=-.281]
# Epoch 98: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.59, gen_loss=0.468]
# Epoch 99: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.51, gen_loss=-.251]
# Epoch 100: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.33, gen_loss=0.324]
# Epoch 101: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.78, gen_loss=-.123]
# Epoch 102: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.11, gen_loss=-.908]
# Epoch 103: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.39, gen_loss=0.667]
# Epoch 104: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.53, gen_loss=0.412]
# Epoch 105: 100%|█████████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.3, gen_loss=1.14]
# Epoch 106: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.69, gen_loss=-.708]
# Epoch 107: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.08, gen_loss=-.656]
# Epoch 108: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.56, gen_loss=-.389]
# Epoch 109: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-1.85, gen_loss=0.222]
# Epoch 110: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.48, gen_loss=0.786]
# Epoch 111: 100%|████████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-3.1, gen_loss=-.658]
# Epoch 112: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.77, gen_loss=-.351]
# Epoch 113: 100%|██████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.42, gen_loss=0.0332]
# Epoch 114: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.52, gen_loss=0.335]
# Epoch 115: 100%|██████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.69, gen_loss=0.0209]
# Epoch 116: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.99, gen_loss=0.596]
# Epoch 117: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.09, gen_loss=-.464]
# Epoch 118: 100%|██████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.26, gen_loss=0.0816]
# Epoch 119: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-1.89, gen_loss=0.314]
# Epoch 120: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.11, gen_loss=0.517]
# Epoch 121: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.25, gen_loss=0.202]
# Epoch 122: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.31, gen_loss=0.457]
# Epoch 123: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.95, gen_loss=-.686]
# Epoch 124: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.1, gen_loss=-.0797]
# Epoch 125: 100%|██████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.29, gen_loss=0.0738]
# Epoch 126: 100%|██████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.21, gen_loss=-.0474]
# Epoch 127: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.96, gen_loss=-.597]
# Epoch 128: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.46, gen_loss=0.446]
# Epoch 129: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-1.74, gen_loss=0.105]
# Epoch 130: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.24, gen_loss=0.507]
# Epoch 131: 100%|██████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.33, gen_loss=-.0832]
# Epoch 132: 100%|██████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.53, gen_loss=-.0441]
# Epoch 133: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.16, gen_loss=0.414]
# Epoch 134: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.97, gen_loss=1.11]
# Epoch 135: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.97, gen_loss=-.208]
# Epoch 136: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.52, gen_loss=0.713]
# Epoch 137: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.56, gen_loss=-.243]
# Epoch 138: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.51, gen_loss=0.945]
# Epoch 139: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.65, gen_loss=-.284]
# Epoch 140: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.61, gen_loss=0.505]
# Epoch 141: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.61, gen_loss=-.111]
# Epoch 142: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.39, gen_loss=0.44]
# Epoch 143: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-1.93, gen_loss=-.762]
# Epoch 144: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.52, gen_loss=-.285]
# Epoch 145: 100%|██████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.47, gen_loss=0.0597]
# Epoch 146: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.71, gen_loss=0.756]
# Epoch 147: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.59, gen_loss=0.281]
# Epoch 148: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-3.54, gen_loss=0.156]
# Epoch 149: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.57, gen_loss=-.703]
# Epoch 150: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-3.18, gen_loss=-.188]
# Epoch 151: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.22, gen_loss=0.343]
# Epoch 152: 100%|█████████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-3, gen_loss=0.0262]
# Epoch 153: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.23, gen_loss=-.904]
# Epoch 154: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.72, gen_loss=-.367]
# Epoch 155: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.75, gen_loss=0.59]
# Epoch 156: 100%|██████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.19, gen_loss=0.0551]
# Epoch 157: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.53s/batch, disc_loss=-2.69, gen_loss=-.301]
# Epoch 158: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.53s/batch, disc_loss=-2.99, gen_loss=-.209]
# Epoch 159: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.5, gen_loss=0.601]
# Epoch 160: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.29, gen_loss=-.21]
# Epoch 161: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.53s/batch, disc_loss=-2.36, gen_loss=0.746]
# Epoch 162: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.53s/batch, disc_loss=-2.61, gen_loss=0.551]
# Epoch 163: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.51, gen_loss=-.359]
# Epoch 164: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.53s/batch, disc_loss=-2.92, gen_loss=-.234]
# Epoch 165: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.59, gen_loss=0.895]
# Epoch 166: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.45, gen_loss=0.279]
# Epoch 167: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.62, gen_loss=0.112]
# Epoch 168: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.56, gen_loss=0.264]
# Epoch 169: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-3.57, gen_loss=-1.63]
# Epoch 170: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.29, gen_loss=0.351]
# Epoch 171: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.57, gen_loss=0.139]
# Epoch 172: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-3.14, gen_loss=-.466]
# Epoch 173: 100%|██████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-3.12, gen_loss=0.0843]
# Epoch 174: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.51, gen_loss=0.26]
# Epoch 175: 100%|█████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.11, gen_loss=0.00363]
# Epoch 176: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.99, gen_loss=0.477]
# Epoch 177: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.76, gen_loss=-.296]
# Epoch 178: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.51, gen_loss=-.632]
# Epoch 179: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.49, gen_loss=0.396]
# Epoch 180: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.78, gen_loss=1.07]
# Epoch 181: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.55, gen_loss=0.267]
# Epoch 182: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.82, gen_loss=-.811]
# Epoch 183: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.64, gen_loss=-.97]
# Epoch 184: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.52, gen_loss=-.213]
# Epoch 185: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.71, gen_loss=-.103]
# Epoch 186: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.46, gen_loss=0.743]
# Epoch 187: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.46, gen_loss=-.496]
# Epoch 188: 100%|██████████████████████████████████| 45/45 [01:09<00:00,  1.54s/batch, disc_loss=-2.49, gen_loss=-.0515]
# Epoch 189: 100%|███████████████████████████████████| 45/45 [01:09<00:00,  1.55s/batch, disc_loss=-2.33, gen_loss=-.208]
# Epoch 190: 100%|███████████████████████████████████| 45/45 [01:09<00:00,  1.54s/batch, disc_loss=-2.51, gen_loss=0.749]
# Epoch 191: 100%|████████████████████████████████████| 45/45 [01:09<00:00,  1.54s/batch, disc_loss=-3.1, gen_loss=-.356]
# Epoch 192: 100%|███████████████████████████████████| 45/45 [01:09<00:00,  1.54s/batch, disc_loss=-2.38, gen_loss=0.284]
# Epoch 193: 100%|███████████████████████████████████| 45/45 [01:09<00:00,  1.54s/batch, disc_loss=-2.53, gen_loss=0.288]
# Epoch 194: 100%|████████████████████████████████████| 45/45 [01:09<00:00,  1.54s/batch, disc_loss=-2.77, gen_loss=0.34]
# Epoch 195: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.53s/batch, disc_loss=-2.41, gen_loss=-.259]
# Epoch 196: 100%|█████████████████████████████████████| 45/45 [01:08<00:00,  1.53s/batch, disc_loss=-3, gen_loss=-.0365]
# Epoch 197: 100%|██████████████████████████████████████| 45/45 [01:08<00:00,  1.53s/batch, disc_loss=-3, gen_loss=-.613]
# Epoch 198: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.53s/batch, disc_loss=-2.29, gen_loss=-.361]
# Epoch 199: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.53s/batch, disc_loss=-2.82, gen_loss=0.406]
# Epoch 200: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.53s/batch, disc_loss=-2.67, gen_loss=-.185]
# Epoch 201: 100%|███████████████████████████████████| 45/45 [01:09<00:00,  1.54s/batch, disc_loss=-2.73, gen_loss=0.659]
# Epoch 202: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.53s/batch, disc_loss=-2.55, gen_loss=0.723]
# Epoch 203: 100%|█████████████████████████████████| 45/45 [01:08<00:00,  1.53s/batch, disc_loss=-2.59, gen_loss=-.00743]
# Epoch 204: 100%|███████████████████████████████████| 45/45 [01:09<00:00,  1.54s/batch, disc_loss=-2.35, gen_loss=0.505]
# Epoch 205: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.72, gen_loss=0.474]
# Epoch 206: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-3.08, gen_loss=-.383]
# Epoch 207: 100%|████████████████████████████████████| 45/45 [01:09<00:00,  1.55s/batch, disc_loss=-2.87, gen_loss=1.27]
# Epoch 208: 100%|███████████████████████████████████| 45/45 [01:09<00:00,  1.54s/batch, disc_loss=-2.72, gen_loss=0.705]
# Epoch 209: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.79, gen_loss=1.42]
# Epoch 210: 100%|██████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.27, gen_loss=0.0644]
# Epoch 211: 100%|████████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.52, gen_loss=1.26]
# Epoch 212: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.83, gen_loss=0.766]
# Epoch 213: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.27, gen_loss=0.404]
# Epoch 214: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.58, gen_loss=-.259]
# Epoch 215: 100%|██████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.88, gen_loss=0.0114]
# Epoch 216: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.61, gen_loss=0.773]
# Epoch 217: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.81, gen_loss=0.522]
# Epoch 218: 100%|██████████████████████████████████| 45/45 [01:07<00:00,  1.50s/batch, disc_loss=-2.54, gen_loss=-.0759]
# Epoch 219: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.51s/batch, disc_loss=-2.92, gen_loss=-.509]
# Epoch 220: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-3.41, gen_loss=0.372]
# Epoch 221: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-2.99, gen_loss=0.498]
# Epoch 222: 100%|███████████████████████████████████| 45/45 [01:07<00:00,  1.51s/batch, disc_loss=-3.18, gen_loss=-.609]
# Epoch 223: 100%|███████████████████████████████████| 45/45 [01:08<00:00,  1.52s/batch, disc_loss=-2.62, gen_loss=-.276]
# Epoch 224:  84%|█████████████████████████████▌     | 38/45 [00:57<00:10,  1.52s/batch, disc_loss=-3.05, gen_loss=0.178]
